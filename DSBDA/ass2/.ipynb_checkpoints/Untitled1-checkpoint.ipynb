# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as mb

# %%
house = pd.read_csv("House_Price_dataset.csv")

# %%
house
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420       4.0        2.0      3.0      yes        no       no
# 1    12250000  8960       4.0        4.0      4.0      yes        no       no
# 2    12250000  9960       3.0        2.0      2.0      yes        no      yes
# 3    12215000  7500       4.0        2.0      2.0      yes        no      yes
# 4    11410000  7420       4.0        1.0      2.0      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000       2.0        1.0      1.0      yes        no      yes
# 541   1767150  2400       3.0        1.0      1.0       no        no       no
# 542   1750000  3620       2.0        1.0      1.0      yes        no       no
# 543   1750000  2910       3.0        1.0      1.0       no        no       no
# 544   1750000  3850       3.0        1.0      2.0      yes        no       no
#
# ...

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          540 non-null    float64
#  3   bathrooms         540 non-null    float64
#  4   stories           543 non-null    float64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           541 non-null    float64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: float64(4), int64(2), object(7)
# memory usage: 55.5+ KB

# %%
house.dtypes
# Out:
# price                 int64
# area                  int64
# bedrooms            float64
# bathrooms           float64
# stories             float64
# mainroad             object
# guestroom            object
# basement             object
# hotwaterheating      object
# airconditioning      object
# parking             float64
# prefarea             object
# furnishingstatus     object
# dtype: object

# %%
house.shape
# Out:
# (545, 13)

# %%
house.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
house.isna()
# Out:
#      price   area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    False  False     False      False    False     False      False
# 1    False  False     False      False    False     False      False
# 2    False  False     False      False    False     False      False
# 3    False  False     False      False    False     False      False
# 4    False  False     False      False    False     False      False
# ..     ...    ...       ...        ...      ...       ...        ...
# 540  False  False     False      False    False     False      False
# 541  False  False     False      False    False     False      False
# 542  False  False     False      False    False     False      False
# 543  False  False     False      False    False     False      False
# 544  False  False     False      False    False     False      False
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0       False            False            False    False     False
# ...

# %%
house.isna().sum()
# Out:
# price               0
# area                0
# bedrooms            5
# bathrooms           5
# stories             2
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             4
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
house.mean(numeric_only=True)
# Out:
# price        4.766729e+06
# area         5.150541e+03
# bedrooms     2.961111e+00
# bathrooms    1.285185e+00
# stories      1.804788e+00
# parking      6.913124e-01
# dtype: float64

# %%
house.fillna(house[["bedrooms","bathrooms","stories","parking"]].mean(),inplace=True)

# %%
house.isna().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
house
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420       4.0        2.0      3.0      yes        no       no
# 1    12250000  8960       4.0        4.0      4.0      yes        no       no
# 2    12250000  9960       3.0        2.0      2.0      yes        no      yes
# 3    12215000  7500       4.0        2.0      2.0      yes        no      yes
# 4    11410000  7420       4.0        1.0      2.0      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000       2.0        1.0      1.0      yes        no      yes
# 541   1767150  2400       3.0        1.0      1.0       no        no       no
# 542   1750000  3620       2.0        1.0      1.0      yes        no       no
# 543   1750000  2910       3.0        1.0      1.0       no        no       no
# 544   1750000  3850       3.0        1.0      2.0      yes        no       no
#
# ...

# %% [markdown]
# ## DATA INTIGRATION

# %%
sub1 = house.iloc[:100,:7]

# %%
sub1
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom
# 0   13300000  7420  4.000000        2.0      3.0      yes        no
# 1   12250000  8960  4.000000        4.0      4.0      yes        no
# 2   12250000  9960  3.000000        2.0      2.0      yes        no
# 3   12215000  7500  4.000000        2.0      2.0      yes        no
# 4   11410000  7420  4.000000        1.0      2.0      yes       yes
# ..       ...   ...       ...        ...      ...      ...       ...
# 95   6300000  4100  3.000000        2.0      3.0      yes        no
# 96   6300000  9000  3.000000        1.0      1.0      yes        no
# 97   6300000  6400  3.000000        1.0      1.0      yes       yes
# 98   6293000  6600  2.961111        2.0      3.0      yes        no
# 99   6265000  6000  4.000000        1.0      3.0      yes       yes
#
# [100 rows x 7 columns]

# %%
sub2 = house.iloc[0:100,6:13]

# %%
sub2
# Out:
#    guestroom basement hotwaterheating airconditioning   parking prefarea  \
# 0         no       no              no             yes  2.000000      yes
# 1         no       no              no             yes  3.000000       no
# 2         no      yes              no              no  2.000000      yes
# 3         no      yes              no             yes  3.000000      yes
# 4        yes      yes              no             yes  2.000000       no
# ..       ...      ...             ...             ...       ...      ...
# 95        no       no              no             yes  2.000000       no
# 96        no      yes              no              no  1.000000      yes
# 97       yes      yes              no             yes  1.000000      yes
# 98        no       no              no             yes  0.691312      yes
# 99       yes      yes              no              no  0.000000      yes
#
#    furnishingstatus
# 0         furnished
# 1         furnished
# 2    semi-furnished
# ...

# %%
sub3 = house.iloc[:50,2:]

# %%
sub3
# Out:
#     bedrooms  bathrooms  stories mainroad guestroom basement hotwaterheating  \
# 0   4.000000   2.000000      3.0      yes        no       no              no
# 1   4.000000   4.000000      4.0      yes        no       no              no
# 2   3.000000   2.000000      2.0      yes        no      yes              no
# 3   4.000000   2.000000      2.0      yes        no      yes              no
# 4   4.000000   1.000000      2.0      yes       yes      yes              no
# 5   3.000000   3.000000      1.0      yes        no      yes              no
# 6   4.000000   3.000000      4.0      yes        no       no              no
# 7   5.000000   3.000000      2.0      yes        no       no              no
# 8   4.000000   1.000000      2.0      yes       yes      yes              no
# 9   3.000000   2.000000      4.0      yes       yes       no              no
# 10  3.000000   1.000000      2.0      yes        no      yes              no
# ...

# %%
sub4 = house[['price', 'bedrooms', 'bathrooms', 'mainroad',
       'guestroom', 'basement',
       'parking', 'furnishingstatus']]

# %%
sub4
# Out:
#         price  bedrooms  bathrooms mainroad guestroom basement  parking  \
# 0    13300000       4.0        2.0      yes        no       no      2.0
# 1    12250000       4.0        4.0      yes        no       no      3.0
# 2    12250000       3.0        2.0      yes        no      yes      2.0
# 3    12215000       4.0        2.0      yes        no      yes      3.0
# 4    11410000       4.0        1.0      yes       yes      yes      2.0
# ..        ...       ...        ...      ...       ...      ...      ...
# 540   1820000       2.0        1.0      yes        no      yes      2.0
# 541   1767150       3.0        1.0       no        no       no      0.0
# 542   1750000       2.0        1.0      yes        no       no      0.0
# 543   1750000       3.0        1.0       no        no       no      0.0
# 544   1750000       3.0        1.0      yes        no       no      0.0
#
#     furnishingstatus
# 0          furnished
# 1          furnished
# 2     semi-furnished
# ...

# %%
merge1 = pd.concat([sub1,sub2],axis=1)
merge1
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom guestroom  \
# 0   13300000  7420  4.000000        2.0      3.0      yes        no        no
# 1   12250000  8960  4.000000        4.0      4.0      yes        no        no
# 2   12250000  9960  3.000000        2.0      2.0      yes        no        no
# 3   12215000  7500  4.000000        2.0      2.0      yes        no        no
# 4   11410000  7420  4.000000        1.0      2.0      yes       yes       yes
# ..       ...   ...       ...        ...      ...      ...       ...       ...
# 95   6300000  4100  3.000000        2.0      3.0      yes        no        no
# 96   6300000  9000  3.000000        1.0      1.0      yes        no        no
# 97   6300000  6400  3.000000        1.0      1.0      yes       yes       yes
# 98   6293000  6600  2.961111        2.0      3.0      yes        no        no
# 99   6265000  6000  4.000000        1.0      3.0      yes       yes       yes
#
# ...

# %% [markdown]
# ## DATA TRANSFORMATION

# %%
house.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
house
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420       4.0        2.0      3.0      yes        no       no
# 1    12250000  8960       4.0        4.0      4.0      yes        no       no
# 2    12250000  9960       3.0        2.0      2.0      yes        no      yes
# 3    12215000  7500       4.0        2.0      2.0      yes        no      yes
# 4    11410000  7420       4.0        1.0      2.0      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000       2.0        1.0      1.0      yes        no      yes
# 541   1767150  2400       3.0        1.0      1.0       no        no       no
# 542   1750000  3620       2.0        1.0      1.0      yes        no       no
# 543   1750000  2910       3.0        1.0      1.0       no        no       no
# 544   1750000  3850       3.0        1.0      2.0      yes        no       no
#
# ...

# %%
sns.scatterplot(data=house, x=house["area"], y=house["price"], hue="furnishingstatus")
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %%
# Count the number of occurrences of each unique value in the 'furnishingstatus' column
furnishingstatus_counts = house["furnishingstatus"].value_counts()
furnishingstatus_labels = furnishingstatus_counts.index
mb.pie(furnishingstatus_counts, labels=furnishingstatus_labels,  autopct='%.1f%%', startangle=140)
mb.title("Distribution of furnishingstatus")
# Equal aspect ratio ensures that pie is drawn as a circle
mb.axis("equal")
mb.show()

# %%
house['mainroad']=house['mainroad'].map({"yes":1,"no":0})

# %%
house['guestroom']=house['guestroom'].map({"yes":1,"no":0})

# %%
house['basement']=house['basement'].map({"yes":1,"no":0})

# %%
house['hotwaterheating']=house['hotwaterheating'].map({"yes":1,"no":0})

# %%
house['airconditioning']=house['airconditioning'].map({"yes":1,"no":0})

# %%
house['prefarea']=house['prefarea'].map({"yes":1,"no":0})

# %%
house['furnishingstatus']=house['furnishingstatus'].map({"unfurnished":0,"furnished":1,"semi-furnished":2})

# %%
house

# %% [markdown]
# ## ERROR CORRECTION

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(house["area"])

# %%
house.shape

# %%
remove = house[house["area"] <= 10000]
plt.boxplot(remove["area"])

# %%
remove.shape

# %%
plt.boxplot(house["stories"])

# %%
remove1 = house[house["stories"] <= 3.0]
plt.boxplot(remove1["stories"])

# %%
remove1.shape

# %%
plt.boxplot(house["parking"])

# %%
remove2 = house[house["parking"] <= 2.0]
plt.boxplot(remove2["parking"])

# %%
remove2.shape

# %% [markdown]
# ## Model Building

# %%
sns.scatterplot(data=house, x=house["area"], y=house["price"], hue="furnishingstatus")

# %%
# Count the number of occurrences of each unique value in the 'furnishingstatus' column
furnishingstatus_counts = house["furnishingstatus"].value_counts()
furnishingstatus_labels = furnishingstatus_counts.index
plt.pie(furnishingstatus_counts, labels=furnishingstatus_labels,  autopct='%.1f%%', startangle=140)
plt.title("Distribution of furnishingstatus")
# Equal aspect ratio ensures that pie is drawn as a circle
plt.axis("equal")
plt.show()

# %%
corr_mat=house.corr()
sns.heatmap(corr_mat, annot=True, fmt=".1f")

# %%
house

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
x=house[["area"]]
y=house[["price"]]
x_train, x_test, y_train, y_test=train_test_split(x,y,train_size=0.75)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)

# %%
linear_regressor = LinearRegression()
linear_regressor.fit(x_train, y_train)

# %%
y_pred = linear_regressor.predict(x_test)

# %%
linear_regressor.coef_

# %%
linear_regressor.intercept_

# %%
mse = mean_squared_error(y_test, y_pred)
mse

# %%
mae = mean_absolute_error(y_test, y_pred)
mae

# %%
r2 = r2_score(y_test, y_pred)
r2

# %%
new = pd.DataFrame(np.array([[67]]).reshape(1,-1),columns=['area'])
linear_regressor.predict(new)

# %%
mb.title("Area-Price")
mb.xlabel("area")
mb.ylabel("price")
mb.scatter(x_test,y_test,label='actual',color='r')
mb.plot(x_test,y_pred,label='predicted',color='g')
mb.legend()

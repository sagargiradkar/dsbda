# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as mb
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
facebook = pd.read_csv("dataset_Facebook.csv",sep=";")

# %%
facebook
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
facebook.shape
# Out:
# (500, 19)

# %%
facebook.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
facebook.dtypes
# Out:
# Page total likes                                                         int64
# Type                                                                    object
# Category                                                                 int64
# Post Month                                                               int64
# Post Weekday                                                             int64
# Post Hour                                                                int64
# Paid                                                                   float64
# Lifetime Post Total Reach                                                int64
# Lifetime Post Total Impressions                                          int64
# Lifetime Engaged Users                                                   int64
# Lifetime Post Consumers                                                  int64
# Lifetime Post Consumptions                                               int64
# ...

# %%
facebook.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
facebook.isna().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
facebook[["Paid","like","share"]].mean()
# Out:
# Paid       0.278557
# like     177.945892
# share     27.266129
# dtype: float64

# %%
facebook.fillna(facebook[["like","share"]].mean(),inplace=True)

# %%
facebook.Paid.mode()
# Out:
# 0    0.0
# Name: Paid, dtype: float64

# %%
facebook.fillna(facebook["Paid"].mode(),inplace=True)

# %%
facebook.isna().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
facebook.mean(numeric_only=True)
# Out:
# Page total likes                                                       123194.176000
# Category                                                                    1.880000
# Post Month                                                                  7.038000
# Post Weekday                                                                4.150000
# Post Hour                                                                   7.840000
# Paid                                                                        0.278557
# Lifetime Post Total Reach                                               13903.360000
# Lifetime Post Total Impressions                                         29585.948000
# Lifetime Engaged Users                                                    920.344000
# Lifetime Post Consumers                                                   798.772000
# Lifetime Post Consumptions                                               1415.130000
# ...

# %%
facebook.median(numeric_only=True)
# Out:
# Page total likes                                                       129600.0
# Category                                                                    2.0
# Post Month                                                                  7.0
# Post Weekday                                                                4.0
# Post Hour                                                                   9.0
# Paid                                                                        0.0
# Lifetime Post Total Reach                                                5281.0
# Lifetime Post Total Impressions                                          9051.0
# Lifetime Engaged Users                                                    625.5
# Lifetime Post Consumers                                                   551.5
# Lifetime Post Consumptions                                                851.0
# Lifetime Post Impressions by people who have liked your Page             6255.5
# ...

# %%
for column in facebook.columns:
    print(column)
    print(facebook[column].mode(),"\n")
# Out:
# Page total likes
# 0    136393
# Name: Page total likes, dtype: int64
#
# Type
# 0    Photo
# Name: Type, dtype: object
#
# Category
# 0    1
# Name: Category, dtype: int64
#
# Post Month
# 0    10
# Name: Post Month, dtype: int64
#
# Post Weekday
# 0    7
# Name: Post Weekday, dtype: int64
#
# Post Hour
# 0    3
# Name: Post Hour, dtype: int64
#
# Paid
# 0    0.0
# Name: Paid, dtype: float64
#
# Lifetime Post Total Reach
# 0       677
# 1      2232
# 2      2645
# 3      2938
# 4      3322
# 5      3358
# 6      3414
# 7      3528
# 8      3754
# 9      5280
# 10     5290
# 11     6692
# 12     9528
# 13    13544
# 14    32208
# Name: Lifetime Post Total Reach, dtype: int64
#
# Lifetime Post Total Impressions
# 0     4372
# 1     6503
# 2     7004
# 3     8533
# 4     8745
# 5    12735
# Name: Lifetime Post Total Impressions, dtype: int64
#
# Lifetime Engaged Users
# 0    537
# Name: Lifetime Engaged Users, dtype: int64
#
# Lifetime Post Consumers
# 0    182
# 1    298
# 2    319
# ...

# %%
sns.pairplot(facebook)

# %%
sns.countplot(data=facebook,x="Paid",hue="Type")
# Out:
# <Axes: xlabel='Paid', ylabel='count'>

# %%
sns.barplot(x=facebook['Category'],y=facebook['Total Interactions'])
# Out:
# <Axes: xlabel='Category', ylabel='Total Interactions'>

# %%
mb.figure(figsize=(20, 7))
count=facebook["Type"].value_counts()
mb.pie(count,labels=count.index,autopct='%.1f%%')
mb.show()

# %%
subset= facebook[["Type","Post Month","Post Weekday","Post Hour","comment","like","share"]];

# %%
subset
# Out:
#        Type  Post Month  Post Weekday  Post Hour  comment    like  share
# 0     Photo          12             4          3        4    79.0   17.0
# 1    Status          12             3         10        5   130.0   29.0
# 2     Photo          12             3          3        0    66.0   14.0
# 3     Photo          12             2         10       58  1572.0  147.0
# 4     Photo          12             2          3       19   325.0   49.0
# ..      ...         ...           ...        ...      ...     ...    ...
# 495   Photo           1             7          2        5    53.0   26.0
# 496   Photo           1             5          8        0    53.0   22.0
# 497   Photo           1             5          2        4    93.0   18.0
# 498   Photo           1             4         11        7    91.0   38.0
# 499   Photo           1             4          4        0    91.0   28.0
#
# [500 rows x 7 columns]

# %%
subset1 = subset[subset["Type"]=="Status" ]

# %%
subset1
# Out:
#        Type  Post Month  Post Weekday  Post Hour  comment   like  share
# 1    Status          12             3         10        5  130.0   29.0
# 5    Status          12             1          9        1  152.0   33.0
# 8    Status          12             7          3        0  161.0   31.0
# 10   Status          12             5         10        0  233.0   19.0
# 15   Status          12             3         10        4   86.0   18.0
# 18   Status          12             2          3        4   54.0   17.0
# 24   Status          12             6         10        3   99.0   19.0
# 25   Status          12             6          3        0   88.0   18.0
# 26   Status          12             5         11       10  412.0   72.0
# 38   Status          12             7          9       11  227.0   31.0
# 40   Status          12             6         11        7  216.0   39.0
# 46   Status          12             3         11        4  174.0   36.0
# ...

# %%
subset2 = subset[subset["like"]>100]
subset2
# Out:
#        Type  Post Month  Post Weekday  Post Hour  comment    like  share
# 1    Status          12             3         10        5   130.0   29.0
# 3     Photo          12             2         10       58  1572.0  147.0
# 4     Photo          12             2          3       19   325.0   49.0
# 5    Status          12             1          9        1   152.0   33.0
# 6     Photo          12             1          3        3   249.0   27.0
# ..      ...         ...           ...        ...      ...     ...    ...
# 488   Photo           1             7         10       21   277.0   80.0
# 491   Photo           1             6          3        1   105.0   46.0
# 492    Link           1             5         11        0   128.0    9.0
# 493   Photo           1             1          2       17   185.0   55.0
# 494   Photo           1             7         10       10   125.0   41.0
#
# [253 rows x 7 columns]

# %%
subset3 = facebook[['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
       'Post Hour', 'Paid']];
subset3
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
#      Paid
# 0     0.0
# 1     0.0
# ...

# %%
subset4 = facebook[['comment', 'like', 'share', 'Total Interactions']];
subset4
# Out:
#      comment    like  share  Total Interactions
# 0          4    79.0   17.0                 100
# 1          5   130.0   29.0                 164
# 2          0    66.0   14.0                  80
# 3         58  1572.0  147.0                1777
# 4         19   325.0   49.0                 393
# ..       ...     ...    ...                 ...
# 495        5    53.0   26.0                  84
# 496        0    53.0   22.0                  75
# 497        4    93.0   18.0                 115
# 498        7    91.0   38.0                 136
# 499        0    91.0   28.0                 119
#
# [500 rows x 4 columns]

# %%
subset5 = facebook.iloc[:100, 6:15]
subset5
# Out:
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0    0.0                       2752                             5091
# 1    0.0                      10460                            19057
# 2    0.0                       2413                             4373
# 3    1.0                      50128                            87991
# 4    0.0                       7244                            13594
# ..   ...                        ...                              ...
# 95   0.0                       3090                             5744
# 96   0.0                       1101                             2548
# 97   0.0                       2819                             5230
# 98   1.0                      12468                            24917
# 99   0.0                      12776                            21893
#
#     Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                      178                      109
# ...

# %%
#column
pd.concat([subset3,subset4],axis=1)
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
#row
sub = subset1.merge(subset2, how="inner")
sub
# Out:
#       Type  Post Month  Post Weekday  Post Hour  comment   like  share
# 0   Status          12             3         10        5  130.0   29.0
# 1   Status          12             1          9        1  152.0   33.0
# 2   Status          12             7          3        0  161.0   31.0
# 3   Status          12             5         10        0  233.0   19.0
# 4   Status          12             5         11       10  412.0   72.0
# 5   Status          12             7          9       11  227.0   31.0
# 6   Status          12             6         11        7  216.0   39.0
# 7   Status          12             3         11        4  174.0   36.0
# 8   Status          11             4         11        3  226.0   44.0
# 9   Status          10             5          3        7  310.0   61.0
# 10  Status          10             1          4       17  193.0   28.0
# 11  Status          10             7          3        4  217.0   50.0
# ...

# %%
facebook.sort_values(by="Page total likes")
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 499             81370   Photo         2           1             4          4
# 496             81370   Photo         2           1             5          8
# 498             81370   Photo         3           1             4         11
# 497             81370   Photo         1           1             5          2
# 493             85093   Photo         3           1             1          2
# ..                ...     ...       ...         ...           ...        ...
# 10             139441  Status         2          12             5         10
# 11             139441   Photo         2          12             5         10
# 13             139441   Photo         2          12             5          3
# 7              139441   Photo         3          12             7          9
# 0              139441   Photo         2          12             4          3
#
# ...

# %%
facebook.sort_values('Page total likes',ascending=False)
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 8              139441  Status         2          12             7          3
# 1              139441  Status         2          12             3         10
# 12             139441   Photo         2          12             5         10
# 11             139441   Photo         2          12             5         10
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
facebook.transpose()
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
reshape=subset5.head(10)
reshape
# Out:
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
# 5   0.0                      10472                            20849
# 6   1.0                      11692                            19479
# 7   1.0                      13720                            24137
# 8   0.0                      11844                            22538
# 9   0.0                       4694                             8668
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                     178                      109
# 1                    1457                     1361
# 2                     177                      113
# ...

# %%
data_stacked = reshape.stack()
data_stacked
# Out:
# 0  Paid                                                                      0.0
#    Lifetime Post Total Reach                                              2752.0
#    Lifetime Post Total Impressions                                        5091.0
#    Lifetime Engaged Users                                                  178.0
#    Lifetime Post Consumers                                                 109.0
#                                                                            ...
# 9  Lifetime Post Consumers                                                 183.0
#    Lifetime Post Consumptions                                              250.0
#    Lifetime Post Impressions by people who have liked your Page           4309.0
#    Lifetime Post reach by people who like your Page                       2324.0
#    Lifetime People who have liked your Page and engaged with your post     199.0
# Length: 90, dtype: float64

# %%
data_unstacked = data_stacked.unstack()
data_unstacked
# Out:
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                     2752.0                           5091.0
# 1   0.0                    10460.0                          19057.0
# 2   0.0                     2413.0                           4373.0
# 3   1.0                    50128.0                          87991.0
# 4   0.0                     7244.0                          13594.0
# 5   0.0                    10472.0                          20849.0
# 6   1.0                    11692.0                          19479.0
# 7   1.0                    13720.0                          24137.0
# 8   0.0                    11844.0                          22538.0
# 9   0.0                     4694.0                           8668.0
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                   178.0                    109.0
# 1                  1457.0                   1361.0
# 2                   177.0                    113.0
# ...

# %%
pd.pivot_table(facebook,index="Type",values="like",columns="Post Month")
# Out:
# Post Month          1       2          3           4           5           6   \
# Type
# Link         61.500000  114.00  35.333333  151.000000   46.000000         NaN
# Photo       134.571429  196.12  89.406250  179.065217  229.030303  134.065217
# Status             NaN     NaN  25.000000  447.000000  131.333333   88.000000
# Video              NaN     NaN        NaN         NaN         NaN  204.000000
#
# Post Month          7      8           9           10          11          12
# Type
# Link               NaN    NaN         NaN   66.333333  130.000000   53.166667
# Photo       292.113636  209.1  233.806452  141.815222  152.578947  197.258065
# Status      143.285714  118.5  180.250000  283.625000  137.000000  169.333333
# Video       315.000000    NaN  345.000000         NaN  204.333333  143.000000

# %%
pivot_tbl = pd.pivot_table(facebook,index=["Type","Category"],values="like")
pivot_tbl
# Out:
#                        like
# Type   Category
# Link   1          75.650000
#        2          32.000000
#        3          68.000000
# Photo  1         126.280789
#        2         235.857143
#        3         219.753333
# Status 1         136.333333
#        2         182.552632
#        3         151.500000
# Video  1         231.428571

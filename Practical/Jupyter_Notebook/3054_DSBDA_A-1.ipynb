# %%
import pandas as pd
import seaborn as sb

# %%
facebook = pd.read_csv("dataset_Facebook.csv", sep=";")

# %%
facebook
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
facebook.shape
# Out:
# (500, 19)

# %%
facebook.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
facebook.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
facebook.tail()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 495   0.0                       4684                             7536
# 496   0.0                       3480                             6229
# 497   0.0                       3778                             7216
# 498   0.0                       4156                             7564
# 499   NaN                       4188                             7292
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
facebook.dtypes
# Out:
# Page total likes                                                         int64
# Type                                                                    object
# Category                                                                 int64
# Post Month                                                               int64
# Post Weekday                                                             int64
# Post Hour                                                                int64
# Paid                                                                   float64
# Lifetime Post Total Reach                                                int64
# Lifetime Post Total Impressions                                          int64
# Lifetime Engaged Users                                                   int64
# Lifetime Post Consumers                                                  int64
# Lifetime Post Consumptions                                               int64
# ...

# %%
facebook.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
facebook.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
facebook = facebook.fillna(facebook['Paid'].mode())

# %%
facebook = facebook.fillna(facebook['like'].mean())

# %%
facebook = facebook.fillna(facebook[['share']].mean())

# %%
facebook.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   0
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
mean = facebook.mean(numeric_only = True)
mean
# Out:
# Page total likes                                                       123194.176000
# Category                                                                    1.880000
# Post Month                                                                  7.038000
# Post Weekday                                                                4.150000
# Post Hour                                                                   7.840000
# Paid                                                                        0.633892
# Lifetime Post Total Reach                                               13903.360000
# Lifetime Post Total Impressions                                         29585.948000
# Lifetime Engaged Users                                                    920.344000
# Lifetime Post Consumers                                                   798.772000
# Lifetime Post Consumptions                                               1415.130000
# ...

# %%
median = facebook.median(numeric_only = True)
median
# Out:
# Page total likes                                                       129600.0
# Category                                                                    2.0
# Post Month                                                                  7.0
# Post Weekday                                                                4.0
# Post Hour                                                                   9.0
# Paid                                                                        0.0
# Lifetime Post Total Reach                                                5281.0
# Lifetime Post Total Impressions                                          9051.0
# Lifetime Engaged Users                                                    625.5
# Lifetime Post Consumers                                                   551.5
# Lifetime Post Consumptions                                                851.0
# Lifetime Post Impressions by people who have liked your Page             6255.5
# ...

# %%
mode = facebook[["Page total likes"]].mode(numeric_only = True)
mode
# Out:
#    Page total likes
# 0            136393

# %%
mode = facebook[["Category"]].mode(numeric_only = True)
mode
# Out:
#    Category
# 0         1

# %%
mode = facebook[["Post Month"]].mode(numeric_only = True)
mode
# Out:
#    Post Month
# 0          10

# %%
mode = facebook[["Post Weekday"]].mode(numeric_only = True)
mode
# Out:
#    Post Weekday
# 0             7

# %%
mode = facebook[["Post Hour"]].mode(numeric_only = True)
mode
# Out:
#    Post Hour
# 0          3

# %%
mode = facebook[["Paid"]].mode(numeric_only = True)
mode
# Out:
#    Paid
# 0   0.0

# %%
mode = facebook[["Lifetime Post Total Reach"]].mode(numeric_only = True)
mode
# Out:
#     Lifetime Post Total Reach
# 0                         677
# 1                        2232
# 2                        2645
# 3                        2938
# 4                        3322
# 5                        3358
# 6                        3414
# 7                        3528
# 8                        3754
# 9                        5280
# 10                       5290
# 11                       6692
# 12                       9528
# 13                      13544
# 14                      32208

# %%
mode = facebook[["Lifetime Post Total Impressions"]].mode(numeric_only = True)
mode
# Out:
#    Lifetime Post Total Impressions
# 0                             4372
# 1                             6503
# 2                             7004
# 3                             8533
# 4                             8745
# 5                            12735

# %%
mode = facebook[["Lifetime Engaged Users"]].mode(numeric_only = True)
mode
# Out:
#    Lifetime Engaged Users
# 0                     537

# %%
mode = facebook[["Lifetime Post Consumers"]].mode(numeric_only = True)
mode
# Out:
#    Lifetime Post Consumers
# 0                      182
# 1                      298
# 2                      319
# 3                      322
# 4                      335
# 5                      374
# 6                      482
# 7                      503
# 8                      513
# 9                      642

# %%
mode = facebook[["Lifetime Post Impressions by people who have liked your Page"]].mode(numeric_only = True)
mode
# Out:
#    Lifetime Post Impressions by people who have liked your Page
# 0                                               1210
# 1                                               1284
# 2                                               2541
# 3                                               2888
# 4                                               3675
# 5                                               4911
# 6                                               4935
# 7                                               5010
# 8                                               5732

# %%
mode = facebook[["Lifetime Post reach by people who like your Page"]].mode(numeric_only = True)
mode
# Out:
#     Lifetime Post reach by people who like your Page
# 0                                                690
# 1                                                704
# 2                                               1228
# 3                                               1640
# 4                                               1674
# 5                                               1722
# 6                                               2044
# 7                                               2124
# 8                                               2162
# 9                                               2174
# 10                                              2388
# 11                                              2426
# 12                                              2604
# 13                                              2616
# 14                                              2644
# 15                                              2660
# 16                                              2704
# ...

# %%
mode = facebook[["Lifetime People who have liked your Page and engaged with your post"]].mode(numeric_only = True)
mode
# Out:
#    Lifetime People who have liked your Page and engaged with your post
# 0                                                403

# %%
mode = facebook[["comment"]].mode(numeric_only = True)
mode
# Out:
#    comment
# 0        0

# %%
mode = facebook[["like"]].mode(numeric_only = True)
mode
# Out:
#    like
# 0  98.0

# %%
mode = facebook[["share"]].mode(numeric_only = True)
mode
# Out:
#    share
# 0   13.0
# 1   14.0

# %%
mode = facebook[["Total Interactions"]].mode(numeric_only = True)
mode
# Out:
#    Total Interactions
# 0                   0
# 1                  39
# 2                  75

# %%
sb.scatterplot(data=facebook, x="Post Month",y="Total Interactions")
# Out:
# <AxesSubplot:xlabel='Post Month', ylabel='Total Interactions'>

# %%
sb.pairplot(facebook, hue="Type")

# %%
sb.scatterplot(data=facebook, x='like', y='comment')
# Out:
# <AxesSubplot:xlabel='like', ylabel='comment'>

# %%
sb.barplot(data=facebook, x="Type",y="Total Interactions")
# Out:
# <AxesSubplot:xlabel='Type', ylabel='Total Interactions'>

# %%
sb.histplot(data=facebook, x="Type",y="Total Interactions")
# Out:
# <AxesSubplot:xlabel='Type', ylabel='Total Interactions'>

# %%
df = facebook
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
sb1 = df[['Total Interactions','Lifetime Post reach by people who like your Page','comment','share','Lifetime Engaged Users','Lifetime Post Total Impressions','Category','Lifetime Post Consumptions']]

# %%
sb1
# Out:
#      Total Interactions  Lifetime Post reach by people who like your Page  \
# 0                   100                                              1640
# 1                   164                                              6112
# 2                    80                                              1503
# 3                  1777                                             32048
# 4                   393                                              3200
# ..                  ...                                               ...
# 495                  84                                              2876
# 496                  75                                              2104
# 497                 115                                              2388
# 498                 136                                              2452
# 499                 119                                              2200
#
#      comment  share  Lifetime Engaged Users  Lifetime Post Total Impressions  \
# ...

# %%
sb2 = df[['Total Interactions','Lifetime Post reach by people who like your Page','comment','share','Lifetime Engaged Users','Lifetime Post Total Impressions','Category','Lifetime Post Consumptions','Page total likes','Type']]

# %%
sb2
# Out:
#      Total Interactions  Lifetime Post reach by people who like your Page  \
# 0                   100                                              1640
# 1                   164                                              6112
# 2                    80                                              1503
# 3                  1777                                             32048
# 4                   393                                              3200
# ..                  ...                                               ...
# 495                  84                                              2876
# 496                  75                                              2104
# 497                 115                                              2388
# 498                 136                                              2452
# 499                 119                                              2200
#
#      comment  share  Lifetime Engaged Users  Lifetime Post Total Impressions  \
# ...

# %%
sb3 = df[['Total Interactions','Lifetime Post reach by people who like your Page','comment','share','Lifetime Engaged Users','Lifetime Post Total Impressions','Category','Lifetime Post Consumptions','Page total likes','Type','Post Month','Post Weekday','Post Hour']]

# %%
sb3
# Out:
#      Total Interactions  Lifetime Post reach by people who like your Page  \
# 0                   100                                              1640
# 1                   164                                              6112
# 2                    80                                              1503
# 3                  1777                                             32048
# 4                   393                                              3200
# ..                  ...                                               ...
# 495                  84                                              2876
# 496                  75                                              2104
# 497                 115                                              2388
# 498                 136                                              2452
# 499                 119                                              2200
#
#      comment  share  Lifetime Engaged Users  Lifetime Post Total Impressions  \
# ...

# %%
sb4 = sb3[sb3['Type']=='Photo']

# %%
sb4.shape
# Out:
# (426, 13)

# %%
sb5 = sb3[sb2['Type']=='Status']

# %%
sb5.shape
# Out:
# (45, 13)

# %%
merge12 = pd.merge(sb1, sb2)

# %%
merge12
# Out:
#      Total Interactions  Lifetime Post reach by people who like your Page  \
# 0                   100                                              1640
# 1                   164                                              6112
# 2                    80                                              1503
# 3                  1777                                             32048
# 4                   393                                              3200
# ..                  ...                                               ...
# 495                  84                                              2876
# 496                  75                                              2104
# 497                 115                                              2388
# 498                 136                                              2452
# 499                 119                                              2200
#
#      comment  share  Lifetime Engaged Users  Lifetime Post Total Impressions  \
# ...

# %%
merge23 = pd.merge(sb2, sb3, how = "outer")
merge23
# Out:
#      Total Interactions  Lifetime Post reach by people who like your Page  \
# 0                   100                                              1640
# 1                   164                                              6112
# 2                    80                                              1503
# 3                  1777                                             32048
# 4                   393                                              3200
# ..                  ...                                               ...
# 495                  84                                              2876
# 496                  75                                              2104
# 497                 115                                              2388
# 498                 136                                              2452
# 499                 119                                              2200
#
#      comment  share  Lifetime Engaged Users  Lifetime Post Total Impressions  \
# ...

# %%
merge12 = pd.merge(sb1, sb2, how="inner")
merge12
# Out:
#      Total Interactions  Lifetime Post reach by people who like your Page  \
# 0                   100                                              1640
# 1                   164                                              6112
# 2                    80                                              1503
# 3                  1777                                             32048
# 4                   393                                              3200
# ..                  ...                                               ...
# 495                  84                                              2876
# 496                  75                                              2104
# 497                 115                                              2388
# 498                 136                                              2452
# 499                 119                                              2200
#
#      comment  share  Lifetime Engaged Users  Lifetime Post Total Impressions  \
# ...

# %%
merge45 = pd.merge(sb4, sb5, how="outer")

# %%
merge45
# Out:
#      Total Interactions  Lifetime Post reach by people who like your Page  \
# 0                   100                                              1640
# 1                    80                                              1503
# 2                  1777                                             32048
# 3                   393                                              3200
# 4                   279                                              9328
# ..                  ...                                               ...
# 466                  67                                              8980
# 467                 255                                             21352
# 468                 166                                              7200
# 469                 587                                             11408
# 470                  34                                              8004
#
#      comment  share  Lifetime Engaged Users  Lifetime Post Total Impressions  \
# ...

# %%
df.sort_values('Post Month', ascending=True)
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 499             81370   Photo         2           1             4          4
# 475             86909   Photo         3           1             6         16
# 476             86909   Photo         1           1             6         10
# 477             86909    Link         1           1             6          4
# 478             86909   Photo         3           1             5         13
# ..                ...     ...       ...         ...           ...        ...
# 29             138895   Video         1          12             4         11
# 28             138895   Photo         2          12             5          3
# 27             138458   Photo         3          12             5          3
# 38             138895  Status         2          12             7          9
# 0              139441   Photo         2          12             4          3
#
# ...

# %%
df.sort_values('Post Month',ascending = False)
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 38             138895  Status         2          12             7          9
# 28             138895   Photo         2          12             5          3
# 29             138895   Video         1          12             4         11
# 30             138895   Photo         2          12             4          2
# ..                ...     ...       ...         ...           ...        ...
# 478             86909   Photo         3           1             5         13
# 477             86909    Link         1           1             6          4
# 476             86909   Photo         1           1             6         10
# 475             86909   Photo         3           1             6         16
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
transpose = df.transpose()

# %%
transpose
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
transpose.shape
# Out:
# (19, 500)

# %%
pd.pivot_table(df,index="Type",values="like",columns="Post Month")
# Out:
# Post Month          1       2          3           4           5           6   \
# Type
# Link         61.500000  114.00  35.333333  151.000000   46.000000         NaN
# Photo       134.571429  196.12  89.406250  179.065217  229.030303  134.065217
# Status             NaN     NaN  25.000000  447.000000  131.333333   88.000000
# Video              NaN     NaN        NaN         NaN         NaN  204.000000
#
# Post Month          7      8           9           10          11          12
# Type
# Link               NaN    NaN         NaN   66.333333  130.000000   53.166667
# Photo       292.113636  209.1  233.806452  141.815222  152.578947  197.258065
# Status      143.285714  118.5  180.250000  283.625000  137.000000  169.333333
# Video       315.000000    NaN  345.000000         NaN  204.333333  143.000000

# %%
pivots = pd.pivot_table(df,index="Category", columns="Type", values="Paid")
pivots
# Out:
# Type      Link     Photo    Status     Video
# Category
# 1          0.3  0.286486  0.333333  0.571429
# 2          0.0  2.208197  0.236842       NaN
# 3          0.0  0.286667  0.000000       NaN

# %%
df.stack()
# Out:
# 0    Page total likes                                                       139441
#      Type                                                                    Photo
#      Category                                                                    2
#      Post Month                                                                 12
#      Post Weekday                                                                4
#                                                                              ...
# 499  Lifetime People who have liked your Page and engaged with your post       316
#      comment                                                                     0
#      like                                                                     91.0
#      share                                                                    28.0
#      Total Interactions                                                        119
# Length: 9500, dtype: object

# %%
df.unstack()
# Out:
# Page total likes    0      139441
#                     1      139441
#                     2      139441
#                     3      139441
#                     4      139441
#                             ...
# Total Interactions  495        84
#                     496        75
#                     497       115
#                     498       136
#                     499       119
# Length: 9500, dtype: object
